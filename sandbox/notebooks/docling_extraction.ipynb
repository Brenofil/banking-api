# %%
import os
from app.utils.logger import get_logger
from app.utils.file_operations import FileOperations
from app.services.documents.docling import DoclingService

logger = get_logger("Sandbox")
password: str = os.getenv("SECRET_PASSWORD", "")

# %%
docling: DoclingService = DoclingService()

converter = docling.get_converter()
